# %% [markdown]
# # QRT Challenge

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import warnings
warnings.filterwarnings('ignore')

from scipy.stats import spearmanr

# configure plot font size
SMALL_SIZE = 6
MEDIUM_SIZE = 7
BIGGER_SIZE = 8
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# configure plot style
plt.style.use('seaborn-whitegrid')

# %%
# read the data
raw_X_train = pd.read_csv('./x_train.csv')
raw_y_train = pd.read_csv('./y_train.csv')

raw_X_train.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1054     206      FR        0.210099       -0.427458       -0.606523
# 1  2049     501      FR       -0.022399       -1.003452       -0.022063
# 2  1924     687      FR        1.395035        1.978665        1.021305
# 3   297     720      DE       -0.983324       -0.849198       -0.839586
# 4  1101     818      FR        0.143807       -0.617038       -0.924990
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.606523            NaN       0.692860            NaN  ...
# 1        0.022063      -0.573520      -1.130838       0.573520  ...
# 2       -1.021305      -0.622021      -1.682587       0.622021  ...
# 3        0.839586      -0.270870       0.563230       0.270870  ...
# 4        0.924990            NaN       0.990324            NaN  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 0         -0.444661 -0.172680 -0.556356 -0.790823 -0.283160 -1.069070
# 1         -1.183194 -1.240300 -0.770457  1.522331  0.828412  0.437419
# 2          1.947273 -0.480700 -0.313338  0.431134  0.487608  0.684884
# 3         -0.976974 -1.114838 -0.507570 -0.499409 -0.236249  0.350938
# 4         -0.526267 -0.541465 -0.424550 -1.088158 -1.011560  0.614338
#
#     FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 0 -0.063404  0.339041  0.124552   -0.002445
# 1  1.831241 -0.659091  0.047114   -0.490365
# 2  0.114836  0.535974  0.743338    0.204952
# 3 -0.417514  0.911652 -0.296168    1.073948
# 4  0.729495  0.245109  1.526606    2.614378
#
# [5 rows x 35 columns]

# %%
raw_y_train.head()
# Out:
#      ID    TARGET
# 0  1054  0.028313
# 1  2049 -0.112516
# 2  1924 -0.180840
# 3   297 -0.260356
# 4  1101 -0.071733

# %%
# print the shape of the data
print('The shape of the X_train data is: {}'.format(raw_X_train.shape))
print('The shape of the y_train data is: {}'.format(raw_y_train.shape))

# print the number of rows containing NaN values
print('The number of rows containing NaN values in X_train is: {}'.format(raw_X_train.isnull().any(axis=1).sum()))
# Out:
# The shape of the X_train data is: (1494, 35)
# The shape of the y_train data is: (1494, 2)
# The number of rows containing NaN values in X_train is: 218

# %%
raw_X_test = pd.read_csv('./x_test.csv')
raw_X_test.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1115     241      FR        0.340083       -0.433604       -0.423521
# 1  1202    1214      FR        0.803209        0.780411        0.601610
# 2  1194    1047      FR        0.795540        0.721954        1.179158
# 3  1084    1139      FR        0.172555       -0.723427       -0.044539
# 4  1135     842      FR        0.949714        0.420236        0.617391
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 0        0.423521       0.165333       0.519419      -0.165333  ...
# 1       -0.601610       0.342802       0.555367      -0.342802  ...
# 2       -1.179158       1.620928       0.666901      -1.620928  ...
# 3        0.044539            NaN      -0.205276            NaN  ...
# 4       -0.617391       0.608561      -0.240856      -0.608561  ...
#
#    FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 0         -0.222525 -0.513180 -0.182048 -0.982546 -0.876632  0.880491
# 1          0.857739 -0.340595 -0.301094 -0.759816 -1.221443 -0.616617
# 2          0.447967  0.796475 -0.367248  0.376055 -0.483363  0.865138
# 3         -0.561295 -0.542606 -0.013291 -0.791119 -0.894309  0.239153
# 4          0.503567 -0.230291 -0.609203 -0.744986 -1.196282  0.176557
#
#     FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 0  0.692242  0.569419 -0.029697   -0.929256
# 1 -0.737496  0.251251  0.753646    0.664086
# 2  0.120079 -1.485642 -0.326450   -0.349747
# 3  0.457457 -0.746863  2.262654    0.642069
# 4  0.312557 -2.219626 -0.509272   -0.488341
#
# [5 rows x 35 columns]

# %%
# merge the X_train and y_train data
raw_train = pd.merge(raw_X_train, raw_y_train, on='ID')
raw_train.head()
# Out:
#      ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 0  1054     206      FR        0.210099       -0.427458       -0.606523
# 1  2049     501      FR       -0.022399       -1.003452       -0.022063
# 2  1924     687      FR        1.395035        1.978665        1.021305
# 3   297     720      DE       -0.983324       -0.849198       -0.839586
# 4  1101     818      FR        0.143807       -0.617038       -0.924990
#
#    FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...   DE_RAIN  \
# 0        0.606523            NaN       0.692860            NaN  ... -0.172680
# 1        0.022063      -0.573520      -1.130838       0.573520  ... -1.240300
# 2       -1.021305      -0.622021      -1.682587       0.622021  ... -0.480700
# 3        0.839586      -0.270870       0.563230       0.270870  ... -1.114838
# 4        0.924990            NaN       0.990324            NaN  ... -0.541465
#
#     FR_RAIN   DE_WIND   FR_WIND   DE_TEMP   FR_TEMP   GAS_RET  COAL_RET  \
# 0 -0.556356 -0.790823 -0.283160 -1.069070 -0.063404  0.339041  0.124552
# 1 -0.770457  1.522331  0.828412  0.437419  1.831241 -0.659091  0.047114
# 2 -0.313338  0.431134  0.487608  0.684884  0.114836  0.535974  0.743338
# 3 -0.507570 -0.499409 -0.236249  0.350938 -0.417514  0.911652 -0.296168
# 4 -0.424550 -1.088158 -1.011560  0.614338  0.729495  0.245109  1.526606
#
#    CARBON_RET    TARGET
# 0   -0.002445  0.028313
# 1   -0.490365 -0.112516
# 2    0.204952 -0.180840
# 3    1.073948 -0.260356
# 4    2.614378 -0.071733
#
# [5 rows x 36 columns]

# %%
# sort data by ID and then by Date
raw_train = raw_train.sort_values(['DAY_ID'])
raw_train.head()
# Out:
#         ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 742   1057       0      FR        0.048418       -0.465067       -0.079296
# 1211  1179       1      FR        0.966997        1.222131        0.331356
# 1408  1327       2      FR       -0.068972       -0.667390       -1.102015
# 1468   111       2      DE       -0.068972       -0.667390       -1.102015
# 329   2016       3      FR       -0.134670       -0.834564       -1.051716
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 742         0.079296            NaN       0.650577            NaN  ...
# 1211       -0.331356       0.405549       0.778627      -0.405549  ...
# 1408        1.102015      -1.080403       0.256736       1.080403  ...
# 1468        1.102015      -1.080403       0.256736       1.080403  ...
# 329         1.051716      -1.881881      -0.612133       1.881881  ...
#
#        DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP   FR_TEMP   GAS_RET  \
# 742  -0.987968 -0.856204 -0.655528 -1.099226  0.279885  0.583874 -1.071996
# 1211 -0.370990 -0.497520 -1.184018 -1.465608  1.349212  0.231602  1.480313
# 1408 -0.344600 -0.372156 -0.623041 -0.926064 -0.148950  0.641235  1.802550
# 1468 -0.344600 -0.372156 -0.623041 -0.926064 -0.148950  0.641235  1.802550
# 329  -1.394561 -1.118297  0.244859  0.488650 -1.710888 -0.951057  0.440121
#
#       COAL_RET  CARBON_RET    TARGET
# 742  -0.074767    0.798003  0.108953
# 1211  0.931562    0.822047 -0.063369
# 1408  1.140920    0.900434  2.575976
# 1468  1.140920    0.900434  0.861270
# 329  -0.064550   -0.032756  0.068905
#
# [5 rows x 36 columns]

# %%
# print the coloumns names
print(raw_train.columns)

# count the number of column names start with 'DE' and 'FR'
print('The number of column names start with DE is: {}'.format(raw_train.columns.str.startswith('DE').sum()))  
print('The number of column names start with FR is: {}'.format(raw_train.columns.str.startswith('FR').sum()))
# Out:
# Index(['ID', 'DAY_ID', 'COUNTRY', 'DE_CONSUMPTION', 'FR_CONSUMPTION',
#        'DE_FR_EXCHANGE', 'FR_DE_EXCHANGE', 'DE_NET_EXPORT', 'FR_NET_EXPORT',
#        'DE_NET_IMPORT', 'FR_NET_IMPORT', 'DE_GAS', 'FR_GAS', 'DE_COAL',
#        'FR_COAL', 'DE_HYDRO', 'FR_HYDRO', 'DE_NUCLEAR', 'FR_NUCLEAR',
#        'DE_SOLAR', 'FR_SOLAR', 'DE_WINDPOW', 'FR_WINDPOW', 'DE_LIGNITE',
#        'DE_RESIDUAL_LOAD', 'FR_RESIDUAL_LOAD', 'DE_RAIN', 'FR_RAIN', 'DE_WIND',
#        'FR_WIND', 'DE_TEMP', 'FR_TEMP', 'GAS_RET', 'COAL_RET', 'CARBON_RET',
#        'TARGET'],
#       dtype='object')
# The number of column names start with DE is: 15
# The number of column names start with FR is: 14

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Fill the NaN data with mean of the column

# %%
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

# Assume df is your DataFrame with missing values in some columns

# Create the IterativeImputer model with a Random Forest estimator
imputer = IterativeImputer(estimator=RandomForestRegressor(n_estimators=100),
                           max_iter=10, random_state=0)

# Fit the imputer model on the dataset to learn the imputation model
imputer.fit(df)

# Perform imputation to fill in the missing values
df_imputed = imputer.transform(df)

# If you want to put the imputed data back into a DataFrame (to keep column names etc.)
df_imputed = pd.DataFrame(df_imputed, columns=df.columns)







# fill the NaN values with the mean of the column
filled_train = raw_train.fillna(raw_train.mean())
filled_train.head()

# check if there are still NaN values
print('The number of rows containing NaN values in filled_train is: {}'.format(filled_train.isnull().any(axis=1).sum()))

# check duplicates in the data
print('The number of duplicates in the data is: {}'.format(filled_train.duplicated().sum()))
# Out:
# The number of rows containing NaN values in filled_train is: 0
# The number of duplicates in the data is: 0

# %% [markdown]
# ### Split the data by country

# %%
from sklearn.preprocessing import StandardScaler

# split the data by value of the column 'COUNTRY'
raw_train_DE = filled_train[filled_train['COUNTRY']=='DE']
raw_train_FR = filled_train[filled_train['COUNTRY']=='FR']

# drop the columns which has name start with 'DE' in raw_train_FR
raw_train_FR = raw_train_FR.drop(raw_train_FR.columns[raw_train_FR.columns.str.startswith('DE')], axis=1)

# drop the columns of 'ID', 'COUNTRY' and 'DAY_ID'
raw_train_DE = raw_train_DE.drop(['ID', 'COUNTRY', 'DAY_ID'], axis=1)
# raw_train_FR.head()

# drop the columns which has name start with 'FR' in raw_train_DE
raw_train_DE = raw_train_DE.drop(raw_train_DE.columns[raw_train_DE.columns.str.startswith('FR')], axis=1)

# drop the columns of 'ID', 'COUNTRY' and 'DAY_ID'
raw_train_FR = raw_train_FR.drop(['ID', 'COUNTRY', 'DAY_ID'], axis=1)
# raw_train_DE.head()
scalor = StandardScaler()
normalized_train_FR = pd.DataFrame(scalor.fit_transform(raw_train_FR), columns=raw_train_FR.columns, index=raw_train_FR.index)
normalized_train_DE = pd.DataFrame(scalor.fit_transform(raw_train_DE), columns=raw_train_DE.columns, index=raw_train_DE.index)

# print the shape of the data
print('The shape of the raw_train_DE data is: {}'.format(raw_train_DE.shape))
print('The shape of the raw_train_FR data is: {}'.format(raw_train_FR.shape))
# Out:
# The shape of the raw_train_DE data is: (643, 19)
# The shape of the raw_train_FR data is: (851, 18)

# %%
normalized_train_FR
# Out:
#       FR_CONSUMPTION  FR_DE_EXCHANGE  FR_NET_EXPORT  FR_NET_IMPORT    FR_GAS  \
# 742        -0.529194       -0.048592       0.673756      -0.673756 -0.712159
# 1211        1.260904       -0.484954       0.799912      -0.799912  1.722982
# 1408       -0.743856        1.038158       0.285738      -0.285738  0.066046
# 329        -0.921226        0.984710      -0.570283       0.570283 -0.354484
# 512        -0.534821       -0.286522      -1.751821       1.751821  0.141687
# ...              ...             ...            ...            ...       ...
# 479        -0.788015       -0.587624      -1.620490       1.620490 -0.235104
# 1451        1.344647       -1.796422      -0.038771       0.038771  0.564511
# 1007       -0.588014        0.154599      -0.745347       0.745347  0.246961
# 873         1.357584        0.351831      -0.035401       0.035401  1.245870
# 1437       -0.436984       -0.062727       0.286815      -0.286815 -0.444577
#
#        FR_COAL  FR_HYDRO  FR_NUCLEAR  FR_SOLAR  FR_WINDPOW  FR_RESIDUAL_LOAD  \
# 742   0.915689  0.486911   -0.025217  0.605411   -1.053637         -0.279334
# 1211 -0.746024  0.517776    1.733844 -0.054370   -0.455178          1.411308
# 1408 -0.709076 -1.038187   -0.047538  0.461275   -1.027792         -0.491815
# 329  -0.618282 -0.519641   -1.261538  2.305274   -0.920710         -0.834152
# 512  -0.707491 -0.533389   -1.551691  2.719806   -0.854050         -0.505085
# ...        ...       ...         ...       ...         ...               ...
# 479  -0.693386 -0.517064   -1.589732  0.488548   -0.707292         -0.628042
# 1451  1.052464  0.717993    1.384404 -0.191602    0.572233          1.220769
# 1007 -0.727699 -1.015521   -1.115112  0.987104   -0.535717         -0.545089
# 873   0.186424  1.679357    0.597872 -0.857630    1.649784          1.036114
# 1437  1.446566  0.584599   -0.125139  0.333335   -1.119481         -0.147766
#
#        FR_RAIN   FR_WIND   FR_TEMP   GAS_RET  COAL_RET  CARBON_RET    TARGET
# 742  -0.875570 -1.133763  0.593392 -1.018985 -0.138225    0.659895  0.061518
# 1211 -0.518557 -1.501094  0.233647  1.319951  0.827076    0.681835 -0.106946
# 1408 -0.393777 -0.960152  0.651969  1.615250  1.027898    0.753360  2.473285
# 329  -1.136441  0.458229 -0.974098  0.366720 -0.128425   -0.098146  0.022366
# 512  -0.809745 -0.009763  1.487842 -0.144721  0.461485    0.645175  0.963214
# ...        ...       ...       ...       ...       ...         ...       ...
# 479   2.625382  0.600158 -1.472499  0.230720  0.478796    0.292845  0.087986
# 1451 -0.225040 -0.496525 -0.398206 -0.413788  1.635834    0.879488 -0.066274
# 1007 -0.259683  1.095179 -0.317637 -0.020316  0.002719   -0.214975 -0.460940
# 873  -0.004089  0.091731  0.005715 -0.131585 -0.673706    0.127745 -2.981702
# 1437  0.711404 -0.916605  0.768647  0.658664  0.008810    0.107799 -0.016036
#
# [851 rows x 18 columns]

# %%
normalized_train_DE
# Out:
#       DE_CONSUMPTION  DE_FR_EXCHANGE  DE_NET_EXPORT  DE_NET_IMPORT    DE_GAS  \
# 1468       -0.658459       -0.940896      -0.809374       0.809374  0.487736
# 680        -0.754852       -0.889974      -1.671308       1.671308  0.912712
# 991        -0.994273        0.321155      -0.946904       0.946904  0.289372
# 1356       -0.472752        0.177018      -0.374711       0.374711 -0.504829
# 713        -0.972109        1.500201       0.619321      -0.619321  0.166254
# ...              ...             ...            ...            ...       ...
# 168        -2.292337       -1.041110      -1.386164       1.386164 -1.022607
# 1136        0.913570        0.834461       1.136315      -1.136315 -0.580958
# 577        -0.488936        0.608022      -0.269495       0.269495  0.680250
# 986        -0.624901       -0.099110       0.204204      -0.204204 -0.686944
# 1465        1.507154       -0.287017       0.710795      -0.710795  1.140126
#
#        DE_COAL  DE_HYDRO  DE_NUCLEAR  DE_SOLAR  DE_WINDPOW  DE_LIGNITE  \
# 1468  0.010372  1.089236    0.755288 -0.449723   -0.538899   -0.029609
# 680  -0.491340  1.281635   -1.588061  1.127744   -1.212706    0.353397
# 991   0.237626  0.618452   -1.444492  2.069606   -0.978726    0.213457
# 1356  0.661321 -0.299997   -1.457667  1.243964   -0.964388    0.706102
# 713   0.027492 -0.203401   -1.459697  0.888953    0.112392    0.257314
# ...        ...       ...         ...       ...         ...         ...
# 168  -1.395724 -0.458350   -0.805489  0.196157   -0.035614   -2.857613
# 1136 -1.042389 -0.479727    0.032544 -0.072958    1.538127   -1.921155
# 577   0.421362  0.936900   -1.462136  1.686520   -0.679502    0.747548
# 986  -0.305483 -0.966822   -1.455300  1.432856   -0.374070    0.366083
# 1465 -0.253901 -1.251066    0.844007 -1.191049    0.352457    1.093523
#
#       DE_RESIDUAL_LOAD   DE_RAIN   DE_WIND   DE_TEMP   GAS_RET  COAL_RET  \
# 1468          0.458759 -0.317082 -0.811794 -0.170593  1.556808  1.066451
# 680           0.312663 -1.403527  0.018470 -1.889068  0.323906 -0.113770
# 991          -0.051115 -1.383035  0.103571 -0.075134 -0.181133  0.488332
# 1356          0.155037 -0.510851 -0.121121 -0.900274 -0.418228  0.457028
# 713          -0.615742  1.615124  1.401420 -0.492949  1.334896  0.092990
# ...                ...       ...       ...       ...       ...       ...
# 168          -1.237932 -0.049147 -0.785592  0.036689  0.092828  0.201456
# 1136         -1.480337  0.000346 -0.111038  0.003684  0.015405  1.663627
# 577           0.166139 -1.227800  0.235965  1.165819  0.189608  0.505999
# 986          -0.752810 -0.001255  1.083544 -0.785494 -0.058285  0.020084
# 1465          0.992829  0.000346 -0.111038  0.003684 -0.168161 -0.670321
#
#       CARBON_RET    TARGET
# 1468    0.737659  0.681725
# 680    -0.109706  6.681811
# 991     0.629999 -0.116296
# 1356   -0.111418 -0.161795
# 713     2.035678 -0.100409
# ...          ...       ...
# 168     0.380480 -0.229226
# 1136    0.507447 -1.407560
# 577     0.279383 -0.083792
# 986    -0.225966 -0.279451
# 1465    0.115087 -0.000437
#
# [643 rows x 19 columns]

# %% [markdown]
# ## EDA

# %%
# visuliaze the distribution of the value of each column in normalized_train_FR with smaller granularity
plt.figure(figsize=(20, 20))
for i, col in enumerate(normalized_train_FR.columns):
    plt.subplot(5, 5, i+1)
    sns.distplot(normalized_train_FR[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# visuliaze the distribution of the value of each column in normalized_train_DE with smaller granularity
plt.figure(figsize=(20, 20))
for i, col in enumerate(normalized_train_DE.columns):
    plt.subplot(5, 5, i+1)
    sns.distplot(normalized_train_DE[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
normalized_train_FR.var()
# Out:
# FR_CONSUMPTION      1.001176
# FR_DE_EXCHANGE      1.001176
# FR_NET_EXPORT       1.001176
# FR_NET_IMPORT       1.001176
# FR_GAS              1.001176
# FR_COAL             1.001176
# FR_HYDRO            1.001176
# FR_NUCLEAR          1.001176
# FR_SOLAR            1.001176
# FR_WINDPOW          1.001176
# FR_RESIDUAL_LOAD    1.001176
# FR_RAIN             1.001176
# FR_WIND             1.001176
# FR_TEMP             1.001176
# GAS_RET             1.001176
# COAL_RET            1.001176
# CARBON_RET          1.001176
# TARGET              1.001176
# dtype: float64

# %%
# if for each row, one of the value is the largest in the column, then remove this row

# remove the rows which has the outlier value in the column
outlier_train_FR = normalized_train_FR.drop(normalized_train_FR.idxmax(axis=0))
for i in range(5):
    outlier_train_FR = outlier_train_FR.drop(outlier_train_FR.idxmax(axis=0))
plt.figure(figsize=(20, 20))
for i, col in enumerate(outlier_train_FR.columns):
    plt.subplot(5, 5, i+1)
    sns.distplot(outlier_train_FR[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# remove the rows which has the outlier value in the column
outlier_train_DE = normalized_train_DE.drop(normalized_train_DE.idxmax(axis=0))
for i in range(5):
    outlier_train_DE = outlier_train_DE.drop(outlier_train_DE.idxmax(axis=0))
plt.figure(figsize=(20, 20))
for i, col in enumerate(outlier_train_DE.columns):
    plt.subplot(5, 5, i+1)
    sns.distplot(outlier_train_DE[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
X_raw_FR = outlier_train_FR.drop(['TARGET', 'FR_NET_IMPORT'], axis=1)
y_raw_FR = outlier_train_FR['TARGET']

# choose the features with the highest absolute correlation with the target
corr = X_raw_FR.corrwith(y_raw_FR)
corr = abs(corr).sort_values(ascending=False)[:10]

X_FR = X_raw_FR[corr.index]
y_FR = y_raw_FR

X_FR.tail()
# Out:
#       CARBON_RET  FR_WINDPOW   GAS_RET  FR_SOLAR  FR_HYDRO   FR_RAIN  \
# 479     0.292845   -0.707292  0.230720  0.488548 -0.517064  2.625382
# 1451    0.879488    0.572233 -0.413788 -0.191602  0.717993 -0.225040
# 1007   -0.214975   -0.535717 -0.020316  0.987104 -1.015521 -0.259683
# 873     0.127745    1.649784 -0.131585 -0.857630  1.679357 -0.004089
# 1437    0.107799   -1.119481  0.658664  0.333335  0.584599  0.711404
#
#       FR_CONSUMPTION    FR_GAS  FR_NUCLEAR   FR_COAL
# 479        -0.788015 -0.235104   -1.589732 -0.693386
# 1451        1.344647  0.564511    1.384404  1.052464
# 1007       -0.588014  0.246961   -1.115112 -0.727699
# 873         1.357584  1.245870    0.597872  0.186424
# 1437       -0.436984 -0.444577   -0.125139  1.446566

# %% [markdown]
# ##

# %%
# import linear regression model (Base Line)
from sklearn.linear_model import LinearRegression

k = 8
test_size = X_FR.shape[0] // k

best_score = 0
best_n_estimators = 0
for n_estimators in range(0, 1):
    avg_score_val = 0
    avg_score_train = 0
    print('n_estimators: {}'.format(n_estimators))
    for i in range(k):
        # split the data into 5 pieces and use one piece as test data
        X_test = X_FR.iloc[i*test_size:(i+1)*test_size]
        y_test = y_FR.iloc[i*test_size:(i+1)*test_size]
        X_train = pd.concat([X_FR.iloc[:i*test_size], X_FR.iloc[(i+1)*test_size:]])
        y_train = pd.concat([y_FR.iloc[:i*test_size], y_FR.iloc[(i+1)*test_size:]])

        # train the random forest model
        gbr = LinearRegression()
        gbr.fit(X_train, y_train)
        y_pred = gbr.predict(X_test) 

        # evaluate the model
        score = spearmanr(y_pred, y_test).correlation * 100
        avg_score_val += score
        # print('(Validation) Score on {}th fold: {:.2f}'.format(i+1, score))
        y_pred_train = gbr.predict(X_train)
        score = spearmanr(y_pred_train, y_train).correlation * 100
        avg_score_train += score
        # print('(Train) Score on {}th fold: {:.2f}'.format(i+1, score))

    avg_score_val /= k
    avg_score_train /= k
    print('Average score on validation data: {:.2f}'.format(avg_score_val))
    print('Average score on train data: {:.2f}'.format(avg_score_train))
    if avg_score_val > best_score:
        best_score = avg_score_val
        best_n_estimators = n_estimators

print('Best score on validation data: {:.2f}'.format(best_score))
print('Best n_estimators: {}'.format(best_n_estimators))
# Out:
# n_estimators: 0
# Average score on validation data: 16.45
# Average score on train data: 21.72
# Best score on validation data: 16.45
# Best n_estimators: 0

# %%
# import SVR
from sklearn.svm import SVR

def SVRegression(df, y_df, C=10, epsilon=0.01):
    model = SVR(kernel='linear', C=C, epsilon=epsilon)
    model.fit(df, y_df)
    return model

C = 20
epsilon = 0.1
k = 10
test_size = X_FR.shape[0] // k

best_score = 0
best_C = 0
for C in range(1, 30, 1):
    avg_score_val = 0
    avg_score_train = 0
    print('C: {}'.format(C))
    for i in range(k):
        # split the data into 5 pieces and use one piece as test data
        X_test = X_FR.iloc[i*test_size:(i+1)*test_size]
        y_test = y_FR.iloc[i*test_size:(i+1)*test_size]
        X_train = pd.concat([X_FR.iloc[:i*test_size], X_FR.iloc[(i+1)*test_size:]])
        y_train = pd.concat([y_FR.iloc[:i*test_size], y_FR.iloc[(i+1)*test_size:]])

        # train the random forest model
        model = SVRegression(X_train, y_train, C, epsilon)
        y_pred = model.predict(X_test) 

        # evaluate the model
        score = spearmanr(y_pred, y_test).correlation * 100
        avg_score_val += score
        # print('(Validation) Score on {}th fold: {:.2f}'.format(i+1, score))
        y_pred_train = model.predict(X_train)
        score = spearmanr(y_pred_train, y_train).correlation * 100
        avg_score_train += score
        # print('(Train) Score on {}th fold: {:.2f}'.format(i+1, score))

    avg_score_val /= k
    avg_score_train /= k
    print('Average score on validation data: {:.2f}'.format(avg_score_val))
    print('Average score on train data: {:.2f}'.format(avg_score_train))
    if avg_score_val > best_score:
        best_score = avg_score_val
        best_C = C

print('Best score on validation data: {:.2f}'.format(best_score))
print('Best C: {}'.format(best_C))
# Out:
# C: 1
# Average score on validation data: 21.30
# Average score on train data: 25.13
# C: 2
# Average score on validation data: 21.13
# Average score on train data: 25.12
# C: 3
# Average score on validation data: 21.14
# Average score on train data: 25.13
# C: 4
# Average score on validation data: 21.08
# Average score on train data: 25.15
# C: 5
# Average score on validation data: 21.17
# Average score on train data: 25.14
# C: 6
# Average score on validation data: 21.21
# Average score on train data: 25.13
# C: 7
# Average score on validation data: 21.13
# Average score on train data: 25.14
# C: 8
# Average score on validation data: 21.33
# Average score on train data: 25.14
# C: 9
# Average score on validation data: 21.27
# Average score on train data: 25.14
# C: 10
# Average score on validation data: 21.19
# Average score on train data: 25.14
# C: 11
# Average score on validation data: 21.24
# Average score on train data: 25.15
# C: 12
# Average score on validation data: 21.22
# Average score on train data: 25.14
# C: 13
# Average score on validation data: 21.24
# Average score on train data: 25.12
# C: 14
# Average score on validation data: 21.24
# Average score on train data: 25.13
# C: 15
# Average score on validation data: 21.22
# Average score on train data: 25.13
# C: 16
# Average score on validation data: 21.29
# Average score on train data: 25.13
# C: 17
# Average score on validation data: 21.31
# Average score on train data: 25.14
# C: 18
# Average score on validation data: 21.19
# Average score on train data: 25.13
# C: 19
# Average score on validation data: 21.23
# Average score on train data: 25.13
# C: 20
# Average score on validation data: 21.24
# Average score on train data: 25.13
# C: 21
# Average score on validation data: 21.11
# Average score on train data: 25.13
# C: 22
# Average score on validation data: 21.35
# Average score on train data: 25.11
# C: 23
# Average score on validation data: 21.21
# Average score on train data: 25.12
# C: 24
# Average score on validation data: 21.22
# Average score on train data: 25.13
# C: 25
# Average score on validation data: 21.33
# Average score on train data: 25.12
# C: 26
# Average score on validation data: 21.32
# Average score on train data: 25.14
# C: 27
# Average score on validation data: 21.23
# Average score on train data: 25.14
# C: 28
# Average score on validation data: 21.35
# Average score on train data: 25.12
# C: 29
# Average score on validation data: 21.22
# Average score on train data: 25.13
# Best score on validation data: 21.35
# Best C: 28

# %%
best_SVR_FR = SVR(kernel='linear', C=best_C, epsilon=epsilon)

# %% [markdown]
# ### For German Data

# %%
X_raw_DE = normalized_train_DE.drop(['TARGET', 'DE_NET_IMPORT'], axis=1)
y_raw_DE = normalized_train_DE['TARGET']

# choose the features with the highest absolute correlation with the target
corr = X_raw_DE.corrwith(y_raw_DE)
corr = abs(corr).sort_values(ascending=False)[:10]

X_DE = X_raw_DE[corr.index]
y_DE = y_raw_DE

X_DE.tail()
# Out:
#       DE_RESIDUAL_LOAD  DE_NET_EXPORT  DE_WINDPOW    DE_GAS   DE_WIND  \
# 168          -1.237932      -1.386164   -0.035614 -1.022607 -0.785592
# 1136         -1.480337       1.136315    1.538127 -0.580958 -0.111038
# 577           0.166139      -0.269495   -0.679502  0.680250  0.235965
# 986          -0.752810       0.204204   -0.374070 -0.686944  1.083544
# 1465          0.992829       0.710795    0.352457  1.140126 -0.111038
#
#       DE_HYDRO   DE_COAL  DE_LIGNITE  DE_FR_EXCHANGE  DE_CONSUMPTION
# 168  -0.458350 -1.395724   -2.857613       -1.041110       -2.292337
# 1136 -0.479727 -1.042389   -1.921155        0.834461        0.913570
# 577   0.936900  0.421362    0.747548        0.608022       -0.488936
# 986  -0.966822 -0.305483    0.366083       -0.099110       -0.624901
# 1465 -1.251066 -0.253901    1.093523       -0.287017        1.507154

# %%
# import linear regression model (Base Line)
from sklearn.linear_model import LinearRegression

k = 8
test_size = X_DE.shape[0] // k

best_score = 0
best_n_estimators = 0
for n_estimators in range(0, 1):
    avg_score_val = 0
    avg_score_train = 0
    print('n_estimators: {}'.format(n_estimators))
    for i in range(k):
        # split the data into 5 pieces and use one piece as test data
        X_test = X_DE.iloc[i*test_size:(i+1)*test_size]
        y_test = y_DE.iloc[i*test_size:(i+1)*test_size]
        X_train = pd.concat([X_DE.iloc[:i*test_size], X_DE.iloc[(i+1)*test_size:]])
        y_train = pd.concat([y_DE.iloc[:i*test_size], y_DE.iloc[(i+1)*test_size:]])

        # train the random forest model
        gbr = LinearRegression()
        gbr.fit(X_train, y_train)
        y_pred = gbr.predict(X_test) 

        # evaluate the model
        score = spearmanr(y_pred, y_test).correlation * 100
        avg_score_val += score
        # print('(Validation) Score on {}th fold: {:.2f}'.format(i+1, score))
        y_pred_train = gbr.predict(X_train)
        score = spearmanr(y_pred_train, y_train).correlation * 100
        avg_score_train += score
        # print('(Train) Score on {}th fold: {:.2f}'.format(i+1, score))

    avg_score_val /= k
    avg_score_train /= k
    print('Average score on validation data: {:.2f}'.format(avg_score_val))
    print('Average score on train data: {:.2f}'.format(avg_score_train))
    if avg_score_val > best_score:
        best_score = avg_score_val
        best_n_estimators = n_estimators

print('Best score on validation data: {:.2f}'.format(best_score))
print('Best n_estimators: {}'.format(best_n_estimators))
# Out:
# n_estimators: 0
# Average score on validation data: 37.84
# Average score on train data: 41.21
# Best score on validation data: 37.84
# Best n_estimators: 0

# %%
# import SVR
from sklearn.svm import SVR

def SVRegression(df, y_df, C=10, epsilon=0.01):
    model = SVR(kernel='linear', C=C, epsilon=epsilon)
    model.fit(df, y_df)
    return model

C = 20
epsilon = 0.1
k = 10
test_size = X_DE.shape[0] // k

best_score = 0
best_C = 0
for C in range(1, 30, 1):
    avg_score_val = 0
    avg_score_train = 0
    print('C: {}'.format(C))
    for i in range(k):
        # split the data into 5 pieces and use one piece as test data
        X_test = X_DE.iloc[i*test_size:(i+1)*test_size]
        y_test = y_DE.iloc[i*test_size:(i+1)*test_size]
        X_train = pd.concat([X_DE.iloc[:i*test_size], X_DE.iloc[(i+1)*test_size:]])
        y_train = pd.concat([y_DE.iloc[:i*test_size], y_DE.iloc[(i+1)*test_size:]])

        # train the random forest model
        model = SVRegression(X_train, y_train, C, epsilon)
        y_pred = model.predict(X_test) 

        # evaluate the model
        score = spearmanr(y_pred, y_test).correlation * 100
        avg_score_val += score
        # print('(Validation) Score on {}th fold: {:.2f}'.format(i+1, score))
        y_pred_train = model.predict(X_train)
        score = spearmanr(y_pred_train, y_train).correlation * 100
        avg_score_train += score
        # print('(Train) Score on {}th fold: {:.2f}'.format(i+1, score))

    avg_score_val /= k
    avg_score_train /= k
    print('Average score on validation data: {:.2f}'.format(avg_score_val))
    print('Average score on train data: {:.2f}'.format(avg_score_train))
    if avg_score_val > best_score:
        best_score = avg_score_val
        best_C = C

print('Best score on validation data: {:.2f}'.format(best_score))
print('Best C: {}'.format(best_C))
# Out:
# C: 1
# Average score on validation data: 39.56
# Average score on train data: 40.42
# C: 2
# Average score on validation data: 39.60
# Average score on train data: 40.51
# C: 3
# Average score on validation data: 39.52
# Average score on train data: 40.51
# C: 4
# Average score on validation data: 39.53
# Average score on train data: 40.52
# C: 5
# Average score on validation data: 39.64
# Average score on train data: 40.54
# C: 6
# Average score on validation data: 39.60
# Average score on train data: 40.54
# C: 7
# Average score on validation data: 39.55
# Average score on train data: 40.53
# C: 8
# Average score on validation data: 39.60
# Average score on train data: 40.55
# C: 9
# Average score on validation data: 39.58
# Average score on train data: 40.54
# C: 10
# Average score on validation data: 39.54
# Average score on train data: 40.54
# C: 11
# Average score on validation data: 39.60
# Average score on train data: 40.54
# C: 12
# Average score on validation data: 39.60
# Average score on train data: 40.54
# C: 13
# Average score on validation data: 39.59
# Average score on train data: 40.54
# C: 14
# Average score on validation data: 39.58
# Average score on train data: 40.55
# C: 15
# Average score on validation data: 39.54
# Average score on train data: 40.55
# C: 16
# Average score on validation data: 39.57
# Average score on train data: 40.54
# C: 17
# Average score on validation data: 39.54
# Average score on train data: 40.54
# C: 18
# Average score on validation data: 39.61
# Average score on train data: 40.55
# C: 19
# Average score on validation data: 39.53
# Average score on train data: 40.54
# C: 20
# Average score on validation data: 39.57
# Average score on train data: 40.55
# C: 21
# Average score on validation data: 39.57
# Average score on train data: 40.54
# C: 22
# Average score on validation data: 39.57
# Average score on train data: 40.54
# C: 23
# Average score on validation data: 39.58
# Average score on train data: 40.55
# C: 24
# Average score on validation data: 39.56
# Average score on train data: 40.54
# C: 25
# Average score on validation data: 39.57
# Average score on train data: 40.54
# C: 26
# Average score on validation data: 39.56
# Average score on train data: 40.54
# C: 27
# Average score on validation data: 39.60
# Average score on train data: 40.55
# C: 28
# Average score on validation data: 39.57
# Average score on train data: 40.54
# C: 29
# Average score on validation data: 39.61
# Average score on train data: 40.54
# Best score on validation data: 39.64
# Best C: 5

# %%
best_SVR_DE = SVR(kernel='linear', C=best_C, epsilon=epsilon)

# %% [markdown]
# ## Merge the Validation

# %%
FR_features = X_FR.columns
DE_features = X_DE.columns

k = 5
test_size = filled_train.shape[0] // k

train_X_all = filled_train.drop(['TARGET'], axis=1)
train_y_all = filled_train['TARGET']

best_C_FR = 28
best_C_DE = 5
epsilon = 0.1

for i in range(k):
    # split the data into 5 pieces and use one piece as test data
    X_test = train_X_all.iloc[i*test_size:(i+1)*test_size]
    y_test = train_y_all.iloc[i*test_size:(i+1)*test_size]
    X_train = pd.concat([train_X_all.iloc[:i*test_size], train_X_all.iloc[(i+1)*test_size:]])
    y_train = pd.concat([train_y_all.iloc[:i*test_size], train_y_all.iloc[(i+1)*test_size:]])

    # if the country is FR, then build the X_train_FR and X_test_FR
    X_train_FR = X_train[X_train['COUNTRY']=='FR'][FR_features]
    y_train_FR = y_train[X_train['COUNTRY']=='FR']
    X_test_FR = X_test[X_test['COUNTRY']=='FR'][FR_features]
    y_test_FR = y_test[X_test['COUNTRY']=='FR']

    # if the country is DE, then build the X_train_DE and X_test_DE
    X_train_DE = X_train[X_train['COUNTRY']=='DE'][DE_features]
    y_train_DE = y_train[X_train['COUNTRY']=='DE']
    X_test_DE = X_test[X_test['COUNTRY']=='DE'][DE_features]
    y_test_DE = y_test[X_test['COUNTRY']=='DE']

    # train the random forest model
    model_FR = SVRegression(X_train_FR, y_train_FR, best_C_FR, epsilon)
    model_DE = SVRegression(X_train_DE, y_train_DE, best_C_DE, epsilon)
    y_pred_FR = model_FR.predict(X_test_FR)
    y_pred_DE = model_DE.predict(X_test_DE)

    # Combine the prediction of FR and DE
    y_pred = np.zeros(y_test.shape)
    y_pred[X_test['COUNTRY']=='FR'] = y_pred_FR
    y_pred[X_test['COUNTRY']=='DE'] = y_pred_DE

    # evaluate the model
    score = spearmanr(y_pred, y_test).correlation * 100
    avg_score_val += score
    # print('(Validation) Score on {}th fold: {:.2f}'.format(i+1, score))
    # y_pred_train = model.predict(X_train)
    # score = spearmanr(y_pred_train, y_train).correlation * 100
    # avg_score_train += score
    # print('(Train) Score on {}th fold: {:.2f}'.format(i+1, score))

avg_score_val /= k
# avg_score_train /= k
print('Average score on validation data: {:.2f}'.format(avg_score_val))
# print('Average score on train data: {:.2f}'.format(avg_score_train))
# Out:
# Average score on validation data: 37.82

# %% [markdown]
# ## Build the final model

# %%
best_SVR_FR = SVRegression(X_FR, y_FR, best_C_FR, epsilon)
best_SVR_DE = SVRegression(X_DE, y_DE, best_C_DE, epsilon)

# %% [markdown]
# ## Final Run on the test dataset

# %%
# read the test data
raw_X_test = pd.read_csv('./x_test.csv')

raw_X_test.fillna(raw_X_test.mean(), inplace=True)

# %%
# predict the target of the test data based on the country and the corresponding model
y_pred = np.zeros(raw_X_test.shape[0])
y_pred[raw_X_test['COUNTRY']=='FR'] = best_SVR_FR.predict(raw_X_test[raw_X_test['COUNTRY']=='FR'][FR_features])
y_pred[raw_X_test['COUNTRY']=='DE'] = best_SVR_DE.predict(raw_X_test[raw_X_test['COUNTRY']=='DE'][DE_features])

# create the submission file
submission = pd.DataFrame({'ID': raw_X_test['ID'], 'TARGET': y_pred})
submission.to_csv('trading_new_hands.csv', index=False)
